# %%
# %%bash
# pwd
# Out:
# /mnt/c/Users/kammi

# %%
# creating a text file for log

# %%
# %%bash
# touch rx_poc.log

# %%
#Adding header to the log file

# %%
# %%bash
# header=$(echo -e "year\tmonth\tday\tobs_temp\tfc_temp")
# echo $header>rx_poc.log

# %%
# %%bash
# touch rx_poc.sh

# %%
# %%bash
# cat rx_poc.sh

# %%
# %%bash
# chmod u+x rx_poc.sh

# %%
# %%bash
# city=Casablanca

# %%
# %%bash
# curl -s wttr.in/$city?T --output weather_report

# %%
# %%bash
# #To extract Current Temperature
# obs_temp=$(curl -s wttr.in/$city?T | grep -m 1 '°.' | grep -Eo -e '-?[[:digit:]].*')
# echo "The current Temperature of $city: $obs_temp"
# Out:
# The current Temperature of : 9(8) °C

# %%
# %%bash
# # To extract the forecast tempearature for noon tomorrow
# fc_temp=$(curl -s wttr.in/$city?T | head -23 | tail -1 | grep '°.' | cut -d 'C' -f2 | grep -Eo -e '-?[[:digit:]].*')
# echo "The forecasted temperature for noon tomorrow for $city : $fc_temp C"
# Out:
# The forecasted temperature for noon tomorrow for  : 4(3) ° C

# %%
# %%bash
# #Store the current hour, day, month, and year in corresponding shell variables
# hour=$(TZ='Morocco/Casablanca' date -u +%H)
# day=$(TZ='Morocco/Casablanca' date -u +%d)
# month=$(TZ='Morocco/Casablanca' date +%m)
# year=$(TZ='Morocco/Casablanca' date +%Y)

# %%
# %%bash
# #Merge the fields into a tab-delimited record, corresponding to a single row in Table 1
# record=$(echo -e "$year\t$month\t$day\t$obs_temp\t$fc_temp C")
# echo $record>>rx_poc.log

# %%
# Commands from Linux terminal
from PIL import Image
from IPython.display import display

img = Image.open("C:\\Users\\kammi\\OneDrive\\Pictures\\Screenshot 2024-01-17 192632.png")

# %%
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1421x896 at 0x1F448067940>
